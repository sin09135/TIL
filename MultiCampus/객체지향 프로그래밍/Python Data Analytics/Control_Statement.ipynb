# %% [markdown]
# # 제어문(Control Statement)
#
# * if ~ else, for ~ in, while

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. 조건문(if ~ else)

# %% [markdown]
# > ## 1) if
#
# * <font color = 'red'>조건문 뒤에 콜론(:) 붙임</font>
# * <font color = 'blue'>들여쓰기(Indentation) 주의</font>

# %%
score = 88

# %%
if score == 88:
    print('획득한 점수는 %d점 입니다.' % score)
# Out:
# 획득한 점수는 88점 입니다.

# %% [markdown]
# > ## 2) if ~ else

# %%
if score == 100:
    print('100점 만점입니다.')
else:
    print('아쉽지만 만점은 아니네요.')
# Out:
# 아쉽지만 만점은 아니네요.

# %% [markdown]
# > ## 3) if ~ elif ~ else

# %% [markdown]
# * 사용자 입력

# %%
score = int(input('점수를 입력하세요: '))
# Out:
# 점수를 입력하세요: 88

# %% [markdown]
# * if 중첩

# %%
if score > 91:
    print('A')
else:
    if score > 81:
        print('B')
# Out:
# B

# %% [markdown]
# * elif 적용

# %%
if score > 91:
    print('A')
elif score > 81:
    print('B')
elif score > 71:
    print('C')
elif score > 61:
    print('D')
else:
    print('F')
# Out:
# B

# %% [markdown]
# # II. 반복문(for ~ in)

# %% [markdown]
# > ## 1) for ~ in with range( )

# %% [markdown]
# * <font color = 'blue'>range(Start, Stop, Step)

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# > ## 2) for ~ in with List_1

# %%
L1 = ['A', 'B', 'C', 'D', 'E']

for i in L1:
    print(i)
# Out:
# A
# B
# C
# D
# E

# %% [markdown]
# > ## 3) for ~ in with List_2

# %%
L2 = [['A', 11], ['B', 22], ['C', 33]]

for i, j in L2:
    print(i, 'and', j)
# Out:
# A and 11
# B and 22
# C and 33

# %% [markdown]
# > ## 4) for ~ in with if ~ else

# %%
score = [99, 88, 55, 77, 66, 55, 100]
num = 0

# %%
for s in score: 
    num = num + 1

    if s > 60: 
        print('%d번 수강생은 수료입니다.' % num)
    else: 
        print('%d번 수강생은 미수료입니다.' % num)
# Out:
# 1번 수강생은 수료입니다.
# 2번 수강생은 수료입니다.
# 3번 수강생은 미수료입니다.
# 4번 수강생은 수료입니다.
# 5번 수강생은 수료입니다.
# 6번 수강생은 미수료입니다.
# 7번 수강생은 수료입니다.

# %% [markdown]
# * enumerate(리스트)
#  - 순서가 있는 자료형의 값을 인덱스와 함께 전달(열거)

# %%
for num, s in enumerate(score):
    num = num + 1

    if s > 60: 
        print('%d번 수강생은 수료입니다.' % num)
    else: 
        print('%d번 수강생은 미수료입니다.' % num)
# Out:
# 1번 수강생은 수료입니다.
# 2번 수강생은 수료입니다.
# 3번 수강생은 미수료입니다.
# 4번 수강생은 수료입니다.
# 5번 수강생은 수료입니다.
# 6번 수강생은 미수료입니다.
# 7번 수강생은 수료입니다.

# %% [markdown]
# > ## 5) for ~ in with break

# %% [markdown]
# * <font color = 'red'>break</font>: 반복문 종료

# %%
for i in range(1, 10):
    if i > 5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# > ## 6) for ~ in with continue

# %% [markdown]
# * <font color = 'blue'>continue</font>: 반복문의 처음으로 돌아감

# %%
score = [99, 88, 55, 77, 66, 55, 100]

for num, s in enumerate(score):
    num = num + 1

    if s < 60:
        continue 
    print('%d번 수강생은 합격입니다.' % num)
# Out:
# 1번 수강생은 합격입니다.
# 2번 수강생은 합격입니다.
# 4번 수강생은 합격입니다.
# 5번 수강생은 합격입니다.
# 7번 수강생은 합격입니다.

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
