# %% [markdown]
# ## 파일 입출력

# %%
import os
os.getcwd() # 파일경로 알려주는 문법 ( pwd 같은 )
# Out:
# '/Users/kimsinwoo/Desktop/multicampus/python/ml'

# %%
import pandas as pd

sample_df = pd.DataFrame({"col1" : [1,2], "col2" : [3,4]})
sample_df # 파일평 test.csv 파일로

# 경로지정해서 출력, 그냥 지금 폴더에 생성하려면 test_csv 만 적으면 됨.
# 경로를 잘못 지정하면 OS Error 가 났다고 표시, 에러 코드 라인과 맨 마지막 줄 에러 만 확인하면 된다.

sample_df.to_csv("output/sample/test.csv", index = False) # 인덱스에 특별한 값이 있다고 하면 index = True

# %% [markdown]
# ### 파일 불러오기
# - sample 폴더 안에 test.csv 불러오기

# %%
# CSV 파일 불러오기
df = pd.read_csv(filepath_or_buffer = "./output/sample/test.csv")
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %% [markdown]
# - df_boston

# %%
df_boston = pd.read_csv("./data/boston.csv")
df_boston
# Out:
#      CRIM    ZN  INDUS  CHAS  NOX  \
# 0    0.01 18.00   2.31  0.00 0.54
# 1    0.03  0.00   7.07  0.00 0.47
# 2    0.03  0.00   7.07  0.00 0.47
# 3    0.03  0.00   2.18  0.00 0.46
# 4    0.07  0.00   2.18  0.00 0.46
# ..    ...   ...    ...   ...  ...
# 501  0.06  0.00  11.93  0.00 0.57
# 502  0.05  0.00  11.93  0.00 0.57
# 503  0.06  0.00  11.93  0.00 0.57
# 504  0.11  0.00  11.93  0.00 0.57
# 505  0.05  0.00  11.93  0.00 0.57
#
#       RM   AGE  DIS  RAD    TAX  \
# 0   6.58 65.20 4.09 1.00 296.00
# 1   6.42 78.90 4.97 2.00 242.00
# 2   7.18 61.10 4.97 2.00 242.00
# 3   7.00 45.80 6.06 3.00 222.00
# 4   7.15 54.20 6.06 3.00 222.00
# ..   ...   ...  ...  ...    ...
# 501 6.59 69.10 2.48 1.00 273.00
# 502 6.12 76.70 2.29 1.00 273.00
# 503 6.98 91.00 2.17 1.00 273.00
# 504 6.79 89.30 2.39 1.00 273.00
# 505 6.03 80.80 2.50 1.00 273.00
#
#      PTRATIO      B  LSTAT  target
# 0      15.30 396.90   4.98   24.00
# 1      17.80 396.90   9.14   21.60
# 2      17.80 392.83   4.03   34.70
# 3      18.70 394.63   2.94   33.40
# 4      18.70 396.90   5.33   36.20
# ..       ...    ...    ...     ...
# 501    21.00 391.99   9.67   22.40
# 502    21.00 396.90   9.08   20.60
# 503    21.00 396.90   5.64   23.90
# 504    21.00 393.45   6.48   22.00
# 505    21.00 396.90   7.88   11.90
#
# [506 rows x 14 columns]

# %% [markdown]
# ## 열 및 행 선택
# - CRIM, ZN, INDUS 열을 선택함

# %%
#result = df_boston[['CRIM','ZN','INDUS']]

cols = ['CRIM','ZN','INDUS'] # 리스트로 따로 받는게 좋음
result = df_boston[cols]
result.head(2)

# key error : 컬럼이 없거나, 오타
# Out:
#    CRIM    ZN  INDUS
# 0  0.01 18.00   2.31
# 1  0.03  0.00   7.07

# %% [markdown]
# - JN 이 18.0에 해당하는 행만 추출

# %%
result = df_boston.loc[df_boston['ZN'] == 18.0]
result.head(2)
# Out:
#    CRIM    ZN  INDUS  CHAS  NOX   RM  \
# 0  0.01 18.00   2.31  0.00 0.54 6.58
#
#     AGE  DIS  RAD    TAX  PTRATIO  \
# 0 65.20 4.09 1.00 296.00    15.30
#
#        B  LSTAT  target
# 0 396.90   4.98   24.00

# %%
# 행 추출의 기본원리는 조건문 - 판다스에서 조건문을 사용하는 방식
# 1.여기서 True 값만 가져오기
df_boston['ZN'] == 18.0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Name: ZN, Length: 506, dtype: bool

# %%
# 2. df로 감싸기
df_boston[df_boston['ZN'] == 18.0]
# Out:
#    CRIM    ZN  INDUS  CHAS  NOX   RM  \
# 0  0.01 18.00   2.31  0.00 0.54 6.58
#
#     AGE  DIS  RAD    TAX  PTRATIO  \
# 0 65.20 4.09 1.00 296.00    15.30
#
#        B  LSTAT  target
# 0 396.90   4.98   24.00

# %% [markdown]
# - AGE 가 50 이상인 데이터만 추출

# %%
result = df_boston[df_boston['AGE'] >= 50] #
result  # 인덱스 번호가 비는 번호 발생 > 인덱스 재정렬 필요
# Out:
#      CRIM    ZN  INDUS  CHAS  NOX  \
# 0    0.01 18.00   2.31  0.00 0.54
# 1    0.03  0.00   7.07  0.00 0.47
# 2    0.03  0.00   7.07  0.00 0.47
# 4    0.07  0.00   2.18  0.00 0.46
# 5    0.03  0.00   2.18  0.00 0.46
# ..    ...   ...    ...   ...  ...
# 501  0.06  0.00  11.93  0.00 0.57
# 502  0.05  0.00  11.93  0.00 0.57
# 503  0.06  0.00  11.93  0.00 0.57
# 504  0.11  0.00  11.93  0.00 0.57
# 505  0.05  0.00  11.93  0.00 0.57
#
#       RM   AGE  DIS  RAD    TAX  \
# 0   6.58 65.20 4.09 1.00 296.00
# 1   6.42 78.90 4.97 2.00 242.00
# 2   7.18 61.10 4.97 2.00 242.00
# 4   7.15 54.20 6.06 3.00 222.00
# 5   6.43 58.70 6.06 3.00 222.00
# ..   ...   ...  ...  ...    ...
# 501 6.59 69.10 2.48 1.00 273.00
# 502 6.12 76.70 2.29 1.00 273.00
# 503 6.98 91.00 2.17 1.00 273.00
# 504 6.79 89.30 2.39 1.00 273.00
# 505 6.03 80.80 2.50 1.00 273.00
#
#      PTRATIO      B  LSTAT  target
# 0      15.30 396.90   4.98   24.00
# 1      17.80 396.90   9.14   21.60
# 2      17.80 392.83   4.03   34.70
# 4      18.70 396.90   5.33   36.20
# 5      18.70 394.12   5.21   28.70
# ..       ...    ...    ...     ...
# 501    21.00 391.99   9.67   22.40
# 502    21.00 396.90   9.08   20.60
# 503    21.00 396.90   5.64   23.90
# 504    21.00 393.45   6.48   22.00
# 505    21.00 396.90   7.88   11.90
#
# [359 rows x 14 columns]

# %%
# 인덱스 추출 포함 (행추출 시 인덱스 재정렬은 필수)
result = df_boston[df_boston['AGE'] >= 50].reset_index(drop = True)
result
# Out:
#      CRIM    ZN  INDUS  CHAS  NOX  \
# 0    0.01 18.00   2.31  0.00 0.54
# 1    0.03  0.00   7.07  0.00 0.47
# 2    0.03  0.00   7.07  0.00 0.47
# 3    0.07  0.00   2.18  0.00 0.46
# 4    0.03  0.00   2.18  0.00 0.46
# ..    ...   ...    ...   ...  ...
# 354  0.06  0.00  11.93  0.00 0.57
# 355  0.05  0.00  11.93  0.00 0.57
# 356  0.06  0.00  11.93  0.00 0.57
# 357  0.11  0.00  11.93  0.00 0.57
# 358  0.05  0.00  11.93  0.00 0.57
#
#       RM   AGE  DIS  RAD    TAX  \
# 0   6.58 65.20 4.09 1.00 296.00
# 1   6.42 78.90 4.97 2.00 242.00
# 2   7.18 61.10 4.97 2.00 242.00
# 3   7.15 54.20 6.06 3.00 222.00
# 4   6.43 58.70 6.06 3.00 222.00
# ..   ...   ...  ...  ...    ...
# 354 6.59 69.10 2.48 1.00 273.00
# 355 6.12 76.70 2.29 1.00 273.00
# 356 6.98 91.00 2.17 1.00 273.00
# 357 6.79 89.30 2.39 1.00 273.00
# 358 6.03 80.80 2.50 1.00 273.00
#
#      PTRATIO      B  LSTAT  target
# 0      15.30 396.90   4.98   24.00
# 1      17.80 396.90   9.14   21.60
# 2      17.80 392.83   4.03   34.70
# 3      18.70 396.90   5.33   36.20
# 4      18.70 394.12   5.21   28.70
# ..       ...    ...    ...     ...
# 354    21.00 391.99   9.67   22.40
# 355    21.00 396.90   9.08   20.60
# 356    21.00 396.90   5.64   23.90
# 357    21.00 393.45   6.48   22.00
# 358    21.00 396.90   7.88   11.90
#
# [359 rows x 14 columns]

# %% [markdown]
# - INDUS 가 5.0 이상이면서 B 가 394 이상인 데이터 추출

# %%
# result = df_boston[(조건식1) & (조건식2) | (조건식3)] 이렇게 틀을 만들어보고 코드 실행해보고 하나씩 집어넣는 빙식

result = df_boston[(df_boston['INDUS'] >= 5.0) & (df_boston['B'] >= 394)].reset_index(drop = True)
result.head(1)
# Out:
#    CRIM   ZN  INDUS  CHAS  NOX   RM  \
# 0  0.03 0.00   7.07  0.00 0.47 6.42
#
#     AGE  DIS  RAD    TAX  PTRATIO  \
# 0 78.90 4.97 2.00 242.00    17.80
#
#        B  LSTAT  target
# 0 396.90   9.14   21.60

# %% [markdown]
# ## iloc 와 loc 차이
# 행과 열에 접근 방식의 차이
# - loc : 레이블 or boolean 값 사용
# - iloc : 인덱스 값 사용

# %% [markdown]
# - iloc 로만 활용해서 추출

# %%
df_boston.iloc[0:3][['CRIM','ZN','INDUS']]
# Out:
#    CRIM    ZN  INDUS
# 0  0.01 18.00   2.31
# 1  0.03  0.00   7.07
# 2  0.03  0.00   7.07

# %% [markdown]
# - loc 활용해서 추출

# %%
df_boston.iloc[0:3][['CRIM','ZN','INDUS']]
df_boston[['CRIM','ZN','INDUS']].loc[0:2]
# Out:
#    CRIM    ZN  INDUS
# 0  0.01 18.00   2.31
# 1  0.03  0.00   7.07
# 2  0.03  0.00   7.07

# %%
df_boston.iloc[0:3,0:3]
# Out:
#    CRIM    ZN  INDUS
# 0  0.01 18.00   2.31
# 1  0.03  0.00   7.07
# 2  0.03  0.00   7.07

# %%
df_boston.loc[0:2,['CRIM','ZN','INDUS']]
# Out:
#    CRIM    ZN  INDUS
# 0  0.01 18.00   2.31
# 1  0.03  0.00   7.07
# 2  0.03  0.00   7.07

# %% [markdown]
# ### iloc 대신 loc 를 써야하는 이유

# %%
result = df_boston.iloc[df_boston['INDUS'] >= 5.0,['CRIM','ZN','INDUS']]
result.head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 result = df_boston.iloc[df_boston['INDUS'] >= 5.0,['CRIM','ZN','INDUS']]
#       2 result.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
#    1595     with suppress(IndexingError):
#    1596         return self._getitem_lowerdim(tup)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:904, in _LocationIndexer._validate_tuple_indexer(self, key)
#     902 for i, k in enumerate(key):
#     903     try:
# --> 904         self._validate_key(k, i)
#     905     except ValueError as err:
#     906         raise ValueError(
#     907             "Location based indexing can only have "
#     908             f"[{self._valid_types}] types"
#     909         ) from err
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1482, in _iLocIndexer._validate_key(self, key, axis)
#    1480 if hasattr(key, "index") and isinstance(key.index, Index):
#    1481     if key.index.inferred_type == "integer":
# -> 1482         raise NotImplementedError(
#    1483             "iLocation based boolean "
#    1484             "indexing on an integer type "
#    1485             "is not available"
#    1486         )
#    1487     raise ValueError(
#    1488         "iLocation based boolean indexing cannot use "
#    1489         "an indexable as a mask"
#    1490     )
#    1491 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
# iloc 사용시 에러남 > loc 에러 안남(행과 열을 같이 사용해야 하니까 loc 가 편리)

result = df_boston.loc[(df_boston['INDUS'] >= 5.0) & (df_boston['B'] >= 394) # 행
                        ,['CRIM','ZN','INDUS']].reset_index(drop = True) #열
result.head()

# %% [markdown]
# ## 결측치 다루기

# %%
import pandas as pd
import numpy as np

np.random.seed(0) # 숫자를 무작위로 추출, 코드를 실행할 떄마다 같은 난수 생성 - 실험조건을 동일하게 맞추기 위해
data = np.random.randint(0,10, size = (10,3), astype = float)

# %%
data[data

# %%
df = pd.DataFrame(data,columns = ['col1','col2','col3']) #외부에서 새로운 데이터 가져옴
df.info()

# %%
df.isna().sum()

# %%
# 평균으로 결측치 대치 해보기
df['col1'].fillna(df['col1'].mean(axis = 0),inplace = True)

# %%
df = pd.DataFrame({
    "이름": ["Evan", "Sara", "Chris", "Messi", "Woods", "Jordan"], 
    "국어": [70, 90, None, None, 100, 85], 
    "영어": [65, 100, None, 90, 70, 80]
})

df

# %% [markdown]
# ## 행추가

# %%
df.loc[6,"이름":"영어"] = ["kim",50,60]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df.loc[6,"이름":"영어"] = ["kim",50,60]
#       2 df
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1835, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1832 # align and set the values
#    1833 if take_split_path:
#    1834     # We have to operate column-wise
# -> 1835     self._setitem_with_indexer_split_path(indexer, value, name)
#    1836 else:
#    1837     self._setitem_single_block(indexer, value, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1920, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1917         self._setitem_single_column(ilocs[0], value, pi)
#    1919     else:
# -> 1920         raise ValueError(
#    1921             "Must have equal len keys and value "
#    1922             "when setting with an iterable"
#    1923         )
#    1925 else:
#    1926     # scalar value
#    1927     for loc in ilocs:
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
# 국어점수가 90점 이상이면 "A"
# 국어점수가 80점~89점 "B"
# 국어점수가 70점~79점 "C"
# 나머지는 F
df['등급'] = "F"

for index, row in df.iterrows():
    
    if row['국어'] >= 90:
        df.loc[index, '등급'] = 'A'
    elif row['국어'] >= 80:
        df.loc[index, '등급'] = 'B'
    elif row['국어'] >= 70:
        df.loc[index, '등급'] = 'C'

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '국어'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 9
#       5 df['등급'] = "F"
#       7 for index, row in df.iterrows():
# ----> 9     if row['국어'] >= 90:
#      10         df.loc[index, '등급'] = 'A'
#      11     elif row['국어'] >= 80:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: '국어'

# %%
df['등급'] = df['국어'].apply(lambda score: 'A' if score >= 90 else ('B' if score >= 80 else ('C' if score >= 70 else 'F')))
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '국어'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df['등급'] = df['국어'].apply(lambda score: 'A' if score >= 90 else ('B' if score >= 80 else ('C' if score >= 70 else 'F')))
#       2 df
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: '국어'

# %% [markdown]
# - np.where 조건식 한번만 적용(if 조건식, 참일 때, 거짓일 때)
# - np.where(조건식, 참, np.where(조건식, 참, 거짓)))

# %% [markdown]
# - np.select(다중조건식, 다중결과값, default = ' ') - default 는 else랑 같은 기능

# %%
# numpy 와 pandas 연계
condition_list = [(df["국어"] >= 90), (df['국어'] >= 80) & (df['국어'] < 90), (df['국어'] >= 70) & (df['국어'] < 80)]
choice_list = ["A", "B", "C"]
df['점수'] = np.select(condition_list, choice_list, default = "F")
df

# %% [markdown]
# ## 날짜 데이터 핸들링
# - 데이터 타입에 따라 해당되는 클래스가 달라짐

# %%
date_string = "2023-03-02"
type(date_string)

# %%
datetime_obj = pd.to_datetime(date_string)

print(datetime_obj)
type(datetime_obj)
print(type(datetime_obj))

# %%
date_list = ["2023-03-02"]
print(type(date_list))

datetime_obj = pd.to_datetime(date_list)
print(datetime_obj)
print(type(datetime_obj))

# %% [markdown]
# ## 데이터 가져오기
# - raw_sales.csv 가져오기

# %%
sales = pd.read_csv('./data/raw_sales.csv')
sales

# %%
sales.info()

# %%
sales.head()

# %%
# 연도, 월, 일 로 칼럼 만들기
sales['Year'] = sales['datesold'].str.split('-').str[0]
sales['Month'] = sales['datesold'].str.split('-').str[1]
sales['Day'] = sales['datesold'].str.split('-').str[2]

# %%
sales.info()

# %% [markdown]
# - 날짜 데이터 변환

# %%
sales['datesold'] = pd.to_datetime(sales['datesold'])

# %%
sales.info()

# %%
sales['Year'] = sales['datesold'].dt.year
sales['Month'] = sales['datesold'].dt.month
sales['day'] = sales['datesold'].dt.day

# %%
sales.info()

# %%
sales = pd.read_csv('./data/raw_sales.csv')
sales

# %%
# 연도, 월, 일 로 칼럼 만들기
sales['Year'] = sales['datesold'].str.split('-').str[0]
sales['Month'] = sales['datesold'].str.split('-').str[1]
sales['Day'] = sales['datesold'].str.split('-').str[2]

# %%
sales.info()

# %% [markdown]
# ## shift 기능
# - 전일 대비, 전주 대비 등 비교에 용이함

# %%
temp_df =sales.loc[:,['datesold','price']].copy()
temp_df.head(3)

# %%
# shift(1, fill_value = 0)
temp_df['shifted_v1'] = temp_df['price'].shift(1,fill_value = 0).astype(int) #fill_value : na 가 뜨는 곳 0으로 처리
temp_df['diff'] = temp_df['price'] - temp_df['shifted_v1']
temp_df.head(3)

# %%
# shift(2, fill_value = 0)
temp_df['shifted_v2'] = temp_df['price'].shift(2,fill_value = 0).astype(int) # 두칸 내려감 
temp_df['diff2'] = temp_df['price'] - temp_df['shifted_v2']
temp_df.head(3)

# %%
# shift(-1, fill_value = 0)
temp_df =sales.loc[:,['datesold','price']].copy() # 거꾸로 올라감
temp_df['shifted_v3'] = temp_df['price'].shift(-1,fill_value = 0).astype(int) # 두칸 내려감 
temp_df['shifted_v4'] = temp_df['price'].shift(-2,fill_value = 0).astype(int)
temp_df.tail(3)

# %%
sales.info()

# %%
# sales['한글날짜'] = 코드작성 예) 2007년 02월 07일
sales['datesold'] = pd.to_datetime(sales['datesold'])
sales['한글날짜'] = sales['datesold'].dt.strftime('%y년 %m월 %d일')
sales.head()

# %% [markdown]
# ## 결측치 이상치 데이터 핸들링

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import statsmodels
import scipy
import seaborn as sns

print(pd.__version__)
print(np.__version__)
print(matplotlib.__version__)
print(statsmodels.__version__)
print(scipy.__version__)
print(sns.__version__)

# %%
DATA_PATH = './'
covidtotals = pd.read_csv(DATA_PATH + "data/covidtotalswithmissings.csv")

# %%
covidtotals.info()

# %%
pd.set_option('display.width', 40)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 20)
pd.options.display.float_format = '{:,.2f}'.format

# %%
covidtotals = covidtotals.set_index('iso_code')

# %%
covidtotals.head()

# %% [markdown]
# ### 결측치 처리
# - 인구통계 컬럼에서 결측치 데이터를 확인
# - 컬럼 방향으로 결측치의 개수를 파악함
# - 5가지 인구 통계 변수 중에서 3개가 누락된 곳, 4개가 누락된 곳 확인

# %%
totvars = ['location','total_cases','total_deaths','total_cases_pm','total_deaths_pm']
demovars = ['population','pop_density','median_age','gdp_per_capita', 'hosp_beds']

# %%
covidtotals[demovars].isnull().sum(axis = 0)

# %%
covidtotals.iloc[2:4,:]
# Out:
#             lastdate location  \
# iso_code
# DZA       2020-06-01  Algeria
# AND       2020-06-01  Andorra
#
#           total_cases  total_deaths  \
# iso_code
# DZA              9394           653
# AND               764            51
#
#           total_cases_pm  \
# iso_code
# DZA               214.22
# AND             9,888.05
#
#           total_deaths_pm  \
# iso_code
# DZA                 14.89
# AND                660.07
#
#             population  pop_density  \
# iso_code
# DZA      43,851,043.00        17.35
# AND          77,265.00       163.75
#
#           median_age  gdp_per_capita  \
# iso_code
# DZA            29.10       13,913.84
# AND              NaN             NaN
#
#           hosp_beds
# iso_code
# DZA            1.90
# AND             NaN

# %%
# 결측치가 3개인 곳 찾아야함
demovars_misscnt = covidtotals[demovars].isnull().sum(axis = 1)
demovars_misscnt
# Out:
# iso_code
# AFG    0
# ALB    0
# DZA    0
# AND    3
# AGO    1
#       ..
# VNM    0
# ESH    3
# YEM    0
# ZMB    0
# ZWE    0
# Length: 210, dtype: int64

# %%
demovars_misscnt.value_counts()
# Out:
# 0    156
# 1     24
# 2     12
# 3     10
# 4      8
# Name: count, dtype: int64

# %% [markdown]
# ### 미션 1.
# - 결측치가 3개 이상인 데이터를 추출하세요!
# - ['location'] + demovars

# %%
covidtotals.loc[demovars_misscnt >= 3, ['location'] + demovars].T # T 행 열 전환
# Out:
# iso_code             AND       AIA  \
# location         Andorra  Anguilla
# population     77,265.00 15,002.00
# pop_density       163.75       NaN
# median_age           NaN       NaN
# gdp_per_capita       NaN       NaN
# hosp_beds            NaN       NaN
#
# iso_code                                    BES  \
# location        Bonaire Sint Eustatius and Saba
# population                            26,221.00
# pop_density                                 NaN
# median_age                                  NaN
# gdp_per_capita                              NaN
# hosp_beds                                   NaN
#
# iso_code                           VGB  \
# location        British Virgin Islands
# population                   30,237.00
# pop_density                     207.97
# median_age                         NaN
# gdp_per_capita                     NaN
# hosp_beds                          NaN
#
# iso_code                   FRO  \
# location        Faeroe Islands
# population           48,865.00
# pop_density              35.31
# median_age                 NaN
# gdp_per_capita             NaN
# hosp_beds                  NaN
#
# iso_code                     FLK  \
# location        Falkland Islands
# population              3,483.00
# pop_density                  NaN
# median_age                   NaN
# gdp_per_capita               NaN
# hosp_beds                    NaN
#
# iso_code              GIB        GRL  \
# location        Gibraltar  Greenland
# population      33,691.00  56,772.00
# pop_density      3,457.10       0.14
# median_age            NaN        NaN
# gdp_per_capita        NaN        NaN
# hosp_beds             NaN        NaN
#
# iso_code             GGY          IMN  \
# location        Guernsey  Isle of Man
# population     67,052.00    85,032.00
# pop_density          NaN       147.87
# median_age           NaN          NaN
# gdp_per_capita       NaN          NaN
# hosp_beds            NaN          NaN
#
# iso_code              JEY  \
# location           Jersey
# population     101,073.00
# pop_density           NaN
# median_age            NaN
# gdp_per_capita        NaN
# hosp_beds             NaN
#
# iso_code                XKX  \
# location             Kosovo
# population     1,932,774.00
# pop_density             NaN
# median_age              NaN
# gdp_per_capita          NaN
# hosp_beds               NaN
#
# iso_code               MSR  \
# location        Montserrat
# population        4,999.00
# pop_density            NaN
# median_age             NaN
# gdp_per_capita         NaN
# hosp_beds              NaN
#
# iso_code                             MNP  \
# location        Northern Mariana Islands
# population                     57,557.00
# pop_density                       119.88
# median_age                           NaN
# gdp_per_capita                       NaN
# hosp_beds                            NaN
#
# iso_code                 TWN  \
# location              Taiwan
# population     23,816,775.00
# pop_density              NaN
# median_age             42.20
# gdp_per_capita           NaN
# hosp_beds                NaN
#
# iso_code                             TCA  \
# location        Turks and Caicos Islands
# population                     38,718.00
# pop_density                        37.31
# median_age                           NaN
# gdp_per_capita                       NaN
# hosp_beds                            NaN
#
# iso_code            VAT  \
# location        Vatican
# population       809.00
# pop_density         NaN
# median_age          NaN
# gdp_per_capita      NaN
# hosp_beds           NaN
#
# iso_code                   ESH
# location        Western Sahara
# population          597,330.00
# pop_density                NaN
# median_age               28.40
# gdp_per_capita             NaN
# hosp_beds                  NaN

# %% [markdown]
# ## Index Alignment
# - 인덱스 값끼리 연산이 이뤄지는 것을 말함. Pandas 에서 제공함

# %%
import pandas as pd

s1 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
s2 = pd.Series([4, 3, 2, 1], index=['d', 'c', 'b', 'a'])

print(s1 + s2)
# Out:
# a    2
# b    4
# c    6
# d    8
# dtype: int64

# %% [markdown]
# ## 코로나 관련 변수만 추출 ##
# - 결측값이 있는지 확인
# - 결측값이 있는 국가 하나 존재
# - totavars 사용

# %%
covidtotals[totvars].isnull().sum(axis=0)
totvarsmisscnt = covidtotals[totvars].isnull().sum(axis=1)
covidtotals.loc[totvarsmisscnt>0].T
# Out:
# iso_code                 HKG
# lastdate          2020-05-26
# location           Hong Kong
# total_cases                0
# total_deaths               0
# total_cases_pm           NaN
# total_deaths_pm          NaN
# population      7,496,988.00
# pop_density         7,039.71
# median_age             44.80
# gdp_per_capita     56,054.92
# hosp_beds                NaN

# %% [markdown]
# ## qcut 사용하기

# %%
covidtotalsonly = covidtotals.loc[:,totvars]
covidtotalsonly
# Out:
#                 location  total_cases  \
# iso_code
# AFG          Afghanistan        15205
# ALB              Albania         1137
# DZA              Algeria         9394
# AND              Andorra          764
# AGO               Angola           86
# ...                  ...          ...
# VNM              Vietnam          328
# ESH       Western Sahara           23
# YEM                Yemen          323
# ZMB               Zambia         1057
# ZWE             Zimbabwe          178
#
#           total_deaths  \
# iso_code
# AFG                257
# ALB                 33
# DZA                653
# AND                 51
# AGO                  4
# ...                ...
# VNM                  0
# ESH                  1
# YEM                 80
# ZMB                  7
# ZWE                  4
#
#           total_cases_pm  \
# iso_code
# AFG               390.59
# ALB               395.09
# DZA               214.22
# AND             9,888.05
# AGO                 2.62
# ...                  ...
# VNM                 3.37
# ESH                38.51
# YEM                10.83
# ZMB                57.50
# ZWE                11.98
#
#           total_deaths_pm
# iso_code
# AFG                  6.60
# ALB                 11.47
# DZA                 14.89
# AND                660.07
# AGO                  0.12
# ...                   ...
# VNM                  0.00
# ESH                  1.67
# YEM                  2.68
# ZMB                  0.38
# ZWE                  0.27
#
# [210 rows x 5 columns]

# %%
covidtotalsonly['total_cases_q'] = pd.qcut(covidtotalsonly['total_cases'],
                                           labels = ['매우낮음','낮음','중간','높음','매우높음'],
                                           q = 5, precision = 0)

covidtotalsonly['total_deaths_q'] =  pd.qcut(covidtotalsonly['total_deaths'],
                                           labels = ['매우낮음','낮음','중간','높음','매우높음'],
                                           q = 5, precision = 0)
covidtotalsonly.head()
# Out:
#              location  total_cases  \
# iso_code
# AFG       Afghanistan        15205
# ALB           Albania         1137
# DZA           Algeria         9394
# AND           Andorra          764
# AGO            Angola           86
#
#           total_deaths  \
# iso_code
# AFG                257
# ALB                 33
# DZA                653
# AND                 51
# AGO                  4
#
#           total_cases_pm  \
# iso_code
# AFG               390.59
# ALB               395.09
# DZA               214.22
# AND             9,888.05
# AGO                 2.62
#
#           total_deaths_pm  \
# iso_code
# AFG                  6.60
# ALB                 11.47
# DZA                 14.89
# AND                660.07
# AGO                  0.12
#
#          total_cases_q total_deaths_q
# iso_code
# AFG                 높음             높음
# ALB                 중간             중간
# DZA                 높음           매우높음
# AND                 중간             중간
# AGO               매우낮음             낮음

# %%
cross_table=pd.crosstab(covidtotalsonly['total_cases_q'],covidtotalsonly['total_deaths_q'])
cross_table
# Out:
# total_deaths_q  매우낮음  낮음  중간  높음  매우높음
# total_cases_q
# 매우낮음              34   7   1   0     0
# 낮음                12  19  10   1     0
# 중간                 1  13  15  13     0
# 높음                 0   0  12  24     6
# 매우높음               0   0   2   4    36

# %%
result = covidtotals.loc[(covidtotalsonly['total_cases_q'] == '중간') & (covidtotalsonly['total_deaths_q'] == '매우낮음'), : ].T
result
# Out:
# iso_code                              CAF
# lastdate                       2020-06-01
# location         Central African Republic
# total_cases                          1011
# total_deaths                            2
# total_cases_pm                     209.33
# total_deaths_pm                      0.41
# population                   4,829,764.00
# pop_density                          7.48
# median_age                          18.30
# gdp_per_capita                     661.24
# hosp_beds                            1.00

# %%
outlier_countries = []

for row_label, row in cross_table.iterrows():
    for col_label, count in row.items():
        if 0< count <= 2:  # 이상치 판단을 위한 기준 값 설정
            outlier_countries.append((row_label, col_label))

print("Outlier Countries:")
for country in outlier_countries:
    print(country)
# Out:
# Outlier Countries:
# ('매우낮음', '중간')
# ('낮음', '높음')
# ('중간', '매우낮음')
# ('매우높음', '중간')

# %%
plt.figure(figsize=(10, 6))
plt.title('Crosstab Heatmap')
plt.xlabel('total_cases_q')
plt.ylabel('total_deaths_q')
plt.imshow(cross_table, cmap='viridis', interpolation='nearest', aspect='auto')

# X, Y 축에 레이블 추가
plt.xticks(range(len(cross_table.columns)), cross_table.columns, rotation=45)
plt.yticks(range(len(cross_table.index)), cross_table.index)

# 컬러 바 추가
plt.colorbar(label='Count')

# 그래프 표시
plt.show()
