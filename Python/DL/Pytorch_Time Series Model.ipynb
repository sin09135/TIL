# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from tqdm import tqdm

# %%
# seed 고정 (rand 함수 실행시 같은 결과 나올 수 있도록)
def seed_everything(seed: int):
    import random, os
    import numpy as np
    import torch

    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(42)

# %% [markdown]
# # 1. RNN Layer

# %%
# input tensor 선언
#input = torch.ones(5, 3) # seq_size, input_dim
input = torch.ones(11, 5, 3) # batch_size, seq_size, input_dim

# RNN Layer 선언
rnn_layer = nn.RNN(input_size=3, hidden_size=10, batch_first=True)
print(rnn_layer.weight_ih_l0.shape)
print(rnn_layer.bias_ih_l0.shape)
print(rnn_layer.weight_hh_l0.shape)
print(rnn_layer.bias_hh_l0.shape)

# print(rnn_layer.weight_ih_l0)
# print(rnn_layer.bias_ih_l0)
# print(rnn_layer.weight_hh_l0)
# print(rnn_layer.bias_hh_l0)
# Out:
# torch.Size([10, 3])
# torch.Size([10])
# torch.Size([10, 10])
# torch.Size([10])

# %%
# output 출력
output, hidden = rnn_layer(input)
print(output.shape)
print(hidden.shape)
# Out:
# torch.Size([11, 5, 10])
# torch.Size([1, 11, 10])

# %% [markdown]
# # 2. LSTM Layer

# %%
# input tensor 정의
# input = torch.ones(7, 3) # seq_size, input_dim
input = torch.ones(11, 7, 3) # batch_size, seq_size, input_dim

# layer 정의
lstm_layer = nn.LSTM(input_size=3, hidden_size=10, batch_first=True)

print(lstm_layer.weight_ih_l0.shape) # 입력/삭제/출력 게이트, hidden state 용 paremeter가 4 종류
print(lstm_layer.bias_ih_l0.shape)
print(lstm_layer.weight_hh_l0.shape)
print(lstm_layer.bias_hh_l0.shape)

# print(lstm_layer.weight_ih_l0)
# print(lstm_layer.bias_ih_l0)
# print(lstm_layer.weight_hh_l0)
# print(lstm_layer.bias_hh_l0)
# Out:
# torch.Size([40, 3])
# torch.Size([40])
# torch.Size([40, 10])
# torch.Size([40])

# %%
# output 출력
output, (hidden, cell) = lstm_layer(input)
print(output.shape)
print(hidden.shape)
print(cell.shape)
# Out:
# torch.Size([11, 7, 10])
# torch.Size([1, 11, 10])
# torch.Size([1, 11, 10])

# %% [markdown]
# # 3. Stock Price Prediction

# %% [markdown]
# ### Naver Stock Web Crawling

# %%
#pip install lxml

# %%
from bs4 import BeautifulSoup
import requests

# 웹 크롤링
code = '005930' # 삼성전자 종목코드
url = 'https://finance.naver.com/item/sise_day.naver?code={}'.format(code)
header = {'User-agent':'Mozilla/5.0'}
req = requests.get(url, headers=header)
html = BeautifulSoup(req.text, "lxml")

pgrr = html.find('td', class_='pgRR')
s = pgrr.a['href'].split('=')
last_page = s[-1]

# dataset 구성
df = None

for page in tqdm(range(1, 100)):
    req = requests.get('{}&page={}'.format(url, page), headers=header)
    df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)

df.head()
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#   1%|          | 1/99 [00:00<00:54,  1.78it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#   2%|▏         | 2/99 [00:01<00:53,  1.81it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#   3%|▎         | 3/99 [00:01<00:52,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#   4%|▍         | 4/99 [00:02<00:52,  1.81it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#
  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  68%|██████▊   | 67/99 [00:36<00:17,  1.84it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  69%|██████▊   | 68/99 [00:37<00:16,  1.84it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  70%|██████▉   | 69/99 [00:37<00:16,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  71%|███████   | 70/99 [00:38<00:15,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  72%|███████▏  | 71/99 [00:39<00:15,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  73%|███████▎  | 72/99 [00:39<00:14,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  74%|███████▎  | 73/99 [00:40<00:14,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  75%|███████▍  | 74/99 [00:40<00:13,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  76%|███████▌  | 75/99 [00:41<00:13,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  77%|███████▋  | 76/99 [00:41<00:12,  1.84it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  78%|███████▊  | 77/99 [00:42<00:12,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  79%|███████▉  | 78/99 [00:42<00:11,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  80%|███████▉  | 79/99 [00:43<00:10,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  81%|████████  | 80/99 [00:43<00:10,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  82%|████████▏ | 81/99 [00:44<00:09,  1.84it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  83%|████████▎ | 82/99 [00:44<00:09,  1.85it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  84%|████████▍ | 83/99 [00:45<00:08,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  85%|████████▍ | 84/99 [00:46<00:08,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  86%|████████▌ | 85/99 [00:46<00:07,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  87%|████████▋ | 86/99 [00:47<00:07,  1.84it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  88%|████████▊ | 87/99 [00:47<00:06,  1.84it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  89%|████████▉ | 88/99 [00:48<00:05,  1.85it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  90%|████████▉ | 89/99 [00:48<00:05,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  91%|█████████ | 90/99 [00:49<00:04,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  92%|█████████▏| 91/99 [00:49<00:04,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  93%|█████████▎| 92/99 [00:50<00:03,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  94%|█████████▍| 93/99 [00:51<00:03,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  95%|█████████▍| 94/99 [00:51<00:02,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  96%|█████████▌| 95/99 [00:52<00:02,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  97%|█████████▋| 96/99 [00:52<00:01,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  98%|█████████▊| 97/99 [00:53<00:01,  1.82it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
#  99%|█████████▉| 98/99 [00:53<00:00,  1.83it/s]<ipython-input-8-8ba18afefe06>:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.concat([df, pd.read_html(req.text, encoding='euc-kr')[0]], ignore_index=True)
# 100%|██████████| 99/99 [00:54<00:00,  1.82it/s]
#            날짜       종가        전일비       시가       고가       저가         거래량
# 0         NaN      NaN        NaN      NaN      NaN      NaN         NaN
# 1  2025.04.18  55300.0    상승  200  55300.0  55600.0  54900.0   5428342.0
# 2  2025.04.17  55100.0    상승  400  54700.0  55300.0  54500.0  10867069.0
# 3  2025.04.16  54700.0  하락  1,900  56000.0  56200.0  54500.0  14437025.0
# 4  2025.04.15  56600.0    상승  400  56300.0  57100.0  56200.0   8998640.0

# %% [markdown]
# ### df 전처리

# %%
# df 전처리
df.dropna(inplace=True)

# 컬럼명 변경
df.columns = ['Date', 'Close', 'Gap', 'Open', 'High', 'Low', 'Amount']

# 불필요 컬럼 제거
df.drop(['Gap'], axis=1, inplace=True)

# 시간순 정렬
df.sort_values(['Date'], inplace=True)
df.reset_index(drop=True, inplace=True)

print(df.shape)
# Out:
# (990, 6)

# %%
# train / test 분리 (train 만 이용해서 학습 및 추론, test는 모델에 input으로 사용 X(미래 값이므로))
train_df = df.loc[df.Date < '2024.04.03'] # 여기까지만 사용
test_df = df.loc[df.Date >= '2024.04.03'] # 모델 학습이 끝난 뒤에 성능 평가용
print(train_df.tail())
print(test_df)

train_df.drop(['Date'], axis=1, inplace=True)

# scaling
scaler = StandardScaler()
scaler.fit(train_df)
s_train_df = scaler.transform(train_df)
s_test_df = scaler.transform(test_df.drop(['Date'], axis=1))
# Out:
#            Date    Close     Open     High      Low      Amount
# 732  2024.03.27  79800.0  79200.0  80000.0  79200.0  17424595.0
# 733  2024.03.28  80800.0  79400.0  81000.0  79200.0  25084812.0
# 734  2024.03.29  82400.0  81200.0  82500.0  80900.0  27126366.0
# 735  2024.04.01  82000.0  83200.0  83300.0  82000.0  20116513.0
# 736  2024.04.02  85000.0  82900.0  85000.0  82900.0  37077944.0
#            Date    Close     Open     High      Low      Amount
# 737  2024.04.03  84100.0  84300.0  85000.0  83500.0  30493347.0
# 738  2024.04.04  85300.0  85200.0  85500.0  84300.0  25248934.0
# 739  2024.04.05  84500.0  84500.0  85000.0  83800.0  18883752.0
# 740  2024.04.08  84500.0  85200.0  86000.0  84500.0  18953232.0
# 741  2024.04.09  83600.0  84500.0  84900.0  83100.0  23725956.0
# ..          ...      ...      ...      ...      ...         ...
# 985  2025.04.14  56200.0  56300.0  56700.0  55800.0  12852613.0
# 986  2025.04.15  56600.0  56300.0  57100.0  56200.0   8998640.0
# 987  2025.04.16  54700.0  56000.0  56200.0  54500.0  14437025.0
# 988  2025.04.17  55100.0  54700.0  55300.0  54500.0  10867069.0
# 989  2025.04.18  55300.0  55300.0  55600.0  54900.0   5428342.0
#
# [253 rows x 6 columns]
# <ipython-input-10-7642b49f6960>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop(['Date'], axis=1, inplace=True)

# %% [markdown]
# ### 학습용 Dataset으로 재구성

# %%
# Define the window sizes
input_window = 30
output_window = 5

# Create the dataset
data = torch.tensor(s_train_df, dtype=torch.float32)
target = torch.tensor(s_train_df.T[0], dtype=torch.float32)

# Create the input and output sequences
X, Y = [], []
for i in range(len(data) - input_window - output_window + 1):
    X.append(data[i:i+input_window])
    Y.append(target[i+input_window:i+input_window+output_window])

# Create the TensorDataset
dataset = TensorDataset(torch.stack(X), torch.stack(Y))
print(dataset[0][0].shape) # seq_size(30일), input_size(close, Open, high, low, amount)
print(dataset[0][1].shape) # output_size(5일치 Close)

# Create the DataLoader
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# Print the dataset size
print(len(dataloader))
# Out:
# torch.Size([30, 5])
# torch.Size([5])
# 22

# %% [markdown]
# ### LSTM Net 구성 및 학습

# %%
# 모델 선언
class MyForecastingModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MyForecastingModel, self).__init__()

        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        # layer 선언
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc1 = nn.Linear(hidden_size, hidden_size//2)
        self.fc2 = nn.Linear(hidden_size//2, output_size)

    def forward(self, x):
        output, (h_out, c_out) = self.lstm(x)
        h_out = h_out.view(-1, self.hidden_size)
        out = F.relu(self.fc1(h_out))
        out = self.fc2(out)
        return out

model = MyForecastingModel(input_size=5, hidden_size=30, output_size=5)

# %% [markdown]
# ### Training loop

# %%
# GPU 지정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
print(model.to(device))
next(model.parameters()).device # model parameter 위치 확인 (cuda or cpu)

# Define the optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()
# Out:
# cpu
# MyForecastingModel(
#   (lstm): LSTM(5, 30, batch_first=True)
#   (fc1): Linear(in_features=30, out_features=15, bias=True)
#   (fc2): Linear(in_features=15, out_features=5, bias=True)
# )

# %%
# Training
num_epoch = 100
losses = []

for epoch in range(num_epoch):
    for i, (inputs, labels) in enumerate(dataloader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        losses.append(loss.item())

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print the loss every 100 iterations
        if i % 100 == 0:
            print(f'Epoch: {epoch+1}/{num_epoch}, Iteration: {i+1}/{len(dataloader)}, Loss: {loss.item():.4f}')
# Out:
# Epoch: 1/100, Iteration: 1/22, Loss: 0.9115
# Epoch: 2/100, Iteration: 1/22, Loss: 0.9920
# Epoch: 3/100, Iteration: 1/22, Loss: 0.5592
# Epoch: 4/100, Iteration: 1/22, Loss: 0.6185
# Epoch: 5/100, Iteration: 1/22, Loss: 0.2320
# Epoch: 6/100, Iteration: 1/22, Loss: 0.1010
# Epoch: 7/100, Iteration: 1/22, Loss: 0.0732
# Epoch: 8/100, Iteration: 1/22, Loss: 0.0546
# Epoch: 9/100, Iteration: 1/22, Loss: 0.0560
# Epoch: 10/100, Iteration: 1/22, Loss: 0.0631
# Epoch: 11/100, Iteration: 1/22, Loss: 0.0287
# Epoch: 12/100, Iteration: 1/22, Loss: 0.0509
# Epoch: 13/100, Iteration: 1/22, Loss: 0.0356
# Epoch: 14/100, Iteration: 1/22, Loss: 0.0493
# Epoch: 15/100, Iteration: 1/22, Loss: 0.0284
# Epoch: 16/100, Iteration: 1/22, Loss: 0.0260
# Epoch: 17/100, Iteration: 1/22, Loss: 0.0400
# Epoch: 18/100, Iteration: 1/22, Loss: 0.0391
# Epoch: 19/100, Iteration: 1/22, Loss: 0.0326
# Epoch: 20/100, Iteration: 1/22, Loss: 0.0339
# Epoch: 21/100, Iteration: 1/22, Loss: 0.0389
# Epoch: 22/100, Iteration: 1/22, Loss: 0.0550
# Epoch: 23/100, Iteration: 1/22, Loss: 0.0408
# Epoch: 24/100, Iteration: 1/22, Loss: 0.0364
# Epoch: 25/100, Iteration: 1/22, Loss: 0.0548
# Epoch: 26/100, Iteration: 1/22, Loss: 0.0411
# Epoch: 27/100, Iteration: 1/22, Loss: 0.0313
# Epoch: 28/100, Iteration: 1/22, Loss: 0.0275
# Epoch: 29/100, Iteration: 1/22, Loss: 0.0254
# Epoch: 30/100, Iteration: 1/22, Loss: 0.0276
# Epoch: 31/100, Iteration: 1/22, Loss: 0.0284
# Epoch: 32/100, Iteration: 1/22, Loss: 0.0375
# Epoch: 33/100, Iteration: 1/22, Loss: 0.0412
# Epoch: 34/100, Iteration: 1/22, Loss: 0.0262
# Epoch: 35/100, Iteration: 1/22, Loss: 0.0280
# Epoch: 36/100, Iteration: 1/22, Loss: 0.0260
# Epoch: 37/100, Iteration: 1/22, Loss: 0.0228
# Epoch: 88/100, Iteration: 1/22, Loss: 0.0136
# Epoch: 89/100, Iteration: 1/22, Loss: 0.0131
# Epoch: 90/100, Iteration: 1/22, Loss: 0.0165
# Epoch: 91/100, Iteration: 1/22, Loss: 0.0118
# Epoch: 92/100, Iteration: 1/22, Loss: 0.0150
# Epoch: 93/100, Iteration: 1/22, Loss: 0.0134
# Epoch: 94/100, Iteration: 1/22, Loss: 0.0150
# Epoch: 95/100, Iteration: 1/22, Loss: 0.0176
# Epoch: 96/100, Iteration: 1/22, Loss: 0.0119
# Epoch: 97/100, Iteration: 1/22, Loss: 0.0132
# Epoch: 98/100, Iteration: 1/22, Loss: 0.0134
# Epoch: 99/100, Iteration: 1/22, Loss: 0.0121
# Epoch: 100/100, Iteration: 1/22, Loss: 0.0215

# %% [markdown]
# ### Loss 시각화

# %%
import matplotlib.pyplot as plt

# Plot the loss values
plt.plot(losses)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# # 모델 평가

# %%
y_real = s_test_df.T[0]
print('스케일링 된 실제 값 : ',y_real)

input = torch.tensor(s_train_df[-30:], dtype=torch.float32)
y_pred = model(input.to(device)).detach().cpu().squeeze().numpy()
print('스케일링 된 예측 값 : ',y_pred)


# 스케일링 원복
print('마지막 5일 실제 종가 : ',scaler.inverse_transform(s_test_df).T[0])
transformed_y_pred = y_pred * np.sqrt(scaler.var_[0]) + scaler.mean_[0]
print('마지막 5일 예측 종가 : ', transformed_y_pred)

print('오차(RMSE) : ', np.sqrt(mean_squared_error(transformed_y_pred, scaler.inverse_transform(s_test_df).T[0])))
# Out:
# 스케일링 된 실제 값 :  [ 1.95711422  2.1168816   2.01037002  2.01037002  1.89054448  1.95711422
#   1.90385843  1.70414921  1.41124236  1.26478893  1.35798656  1.09170761
#   0.89199839  0.8121147   1.22484709  0.91862628  0.97188207  0.97188207
#   1.07839366  1.1449634   1.09170761  1.58432368  1.58432368  1.37130051
#   1.30473077  1.19821919  1.18490524  1.17159129  1.06507971  1.26478893
#   1.19821919  1.10502155  1.18490524  0.86537049  1.03845181  1.09170761
#   0.77217285  0.54583574  0.54583574  0.83874259  0.7854868   1.06507971
#   1.05176576  0.83874259  0.77217285  0.94525418  1.22484709  1.35798656
#   1.15827735  1.38461446  1.57100973  1.62426552  1.41124236  1.49112604
#   1.51775394  1.58432368  1.62426552  1.61095158  1.65089342  1.65089342
#   1.65089342  2.02368396  2.35653266  2.39647451  2.4497303   2.4497303
#   2.4231024   1.99705607  2.30327687  2.43641635  2.30327687  2.32990477
#   1.99705607  1.8106608   1.93048633  1.67752132  1.46449815  1.53106789
#   1.57100973  1.54438184  1.93048633  1.82397474  1.35798656  0.26624283
#   0.41269626  0.70560311  0.53252179  0.70560311  0.8121147   0.89199839
#   1.03845181  1.43787025  1.18490524  1.26478893  1.18490524  1.18490524
#   1.10502155  0.89199839  0.85205654  0.93194023  0.61240548  0.65234732
#  77200. 80200. 78300. 78900. 78300. 78300. 77700. 76100. 75800. 76400.
#  74000. 74300. 74400. 72500. 70000. 69000. 68900. 67500. 66200. 64900.
#  66300. 64400. 63100. 63000. 62600. 63200. 62200. 64700. 64200. 61500.
#  61300. 60600. 61000. 60300. 58900. 59300. 60800. 61000. 59500. 59700.
#  59200. 59000. 57700. 59100. 56600. 55900. 58100. 59600. 59100. 59200.
#  58300. 58700. 57600. 57300. 57500. 57000. 55000. 53000. 50600. 49900.
#  53500. 56700. 56300. 55300. 56400. 56000. 57900. 58300. 56300. 55500.
#  54200. 53600. 53600. 53100. 53700. 54100. 53400. 54000. 54000. 55900.
#  56100. 55600. 54200. 54900. 53100. 53000. 53500. 54400. 53600. 53700.
#  53200. 53400. 54400. 55900. 55400. 57300. 56100. 55300. 54100. 53900.
#  53700. 54300. 53700. 53400. 53500. 54300. 53700. 53700. 52400. 51000.
#  52700. 52900. 54000. 53700. 55600. 55700. 55800. 55800. 56000. 56000.
#  56900. 58700. 58400. 58200. 57300. 57200. 56600. 56300. 54500. 54500.
#  54000. 54300. 53700. 53700. 53600. 54900. 54700. 54700. 57600. 57600.
#  58500. 60200. 61700. 60500. 59800. 61400. 61800. 60200. 57800. 58800.
#  58800. 57600. 56100. 53200. 53500. 53000. 56400. 55200. 56200. 56600.
#  54700. 55100. 55300.]
# 마지막 5일 예측 종가 :  [81065.11783066 80460.40275423 81097.9206592  81097.84634337
#  81114.30327067]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-b4321686ba9c> in <cell line: 0>()
#      12 print('마지막 5일 예측 종가 : ', transformed_y_pred)
#      13
# ---> 14 print('오차(RMSE) : ', np.sqrt(mean_squared_error(transformed_y_pred, scaler.inverse_transform(s_test_df).T[0])))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     563     xp, _ = get_namespace(y_true, y_pred, sample_weight, multioutput)
#     564     _, y_true, y_pred, sample_weight, multioutput = (
# --> 565         _check_reg_targets_with_floating_dtype(
#     566             y_true, y_pred, sample_weight, multioutput, xp=xp
#     567         )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     196     dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
#     197
# --> 198     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     199         y_true, y_pred, multioutput, dtype=dtype_name, xp=xp
#     200     )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype, xp)
#     102     xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
#     103
# --> 104     check_consistent_length(y_true, y_pred)
#     105     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     106     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
# --> 475         raise ValueError(
#     476             "Found input variables with inconsistent numbers of samples: %r"
#     477             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [5, 253]
